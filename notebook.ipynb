# %%
import pandas as pd
import seaborn as sns
import seaborn as sb
import matplotlib.pyplot as mp
import numpy as np

# %%
df = pd.read_csv("Life_expectancy_data_cleaned.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2302 entries, 0 to 2301
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country                          2302 non-null   object
#  1   year                             2302 non-null   int64
#  2   status                           2302 non-null   object
#  3   life_expectancy                  2302 non-null   float64
#  4   adult_mortality                  2302 non-null   float64
#  5   infant_deaths                    2302 non-null   int64
#  6   alcohol                          2302 non-null   float64
#  7   percentage_expenditure           2302 non-null   float64
#  8   hepatitis_b                      2302 non-null   float64
#  9   measles                          2302 non-null   int64
#  10  bmi                              2302 non-null   float64
#  11  under-five_deaths                2302 non-null   int64
# ...

# %%
df.describe()
# Out:
#               year  life_expectancy  adult_mortality  infant_deaths  \
# count  2302.000000      2302.000000      2302.000000    2302.000000
# mean   2007.010426        67.965063       177.391134      35.492615
# std       4.551112         9.484938       128.591530     130.812709
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2003.000000        61.725000        81.000000       1.000000
# 50%    2007.000000        69.900000       157.000000       4.000000
# 75%    2011.000000        74.800000       249.000000      27.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            alcohol  percentage_expenditure  hepatitis_b        measles  \
# count  2302.000000             2302.000000  2302.000000    2302.000000
# mean      4.450088                0.034131    80.373156    2829.097307
# std       3.857304                0.100008    22.343970   12563.517502
# ...

# %%
df.head()
# Out:
#        country  year      status  life_expectancy  adult_mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant_deaths  alcohol  percentage_expenditure  hepatitis_b  measles  ...  \
# 0             62     0.01                0.003659         65.0     1154  ...
# 1             64     0.01                0.003774         62.0      492  ...
# 2             66     0.01                0.003759         64.0      430  ...
# 3             69     0.01                0.004014         67.0     2787  ...
# 4             71     0.01                0.000364         68.0     3013  ...
#
#    diphtheria  hiv/aids       gdp  population  thinness__1-19_years  \
# ...

# %%
missing_percentages = (df.isnull().sum() / len(df)) * 100
missing_percentages = missing_percentages[missing_percentages > 0]
print(missing_percentages)
# Out:
# Series([], dtype: float64)

# %%
df.isnull().sum()
# Out:
# country                            0
# year                               0
# status                             0
# life_expectancy                    0
# adult_mortality                    0
# infant_deaths                      0
# alcohol                            0
# percentage_expenditure             0
# hepatitis_b                        0
# measles                            0
# bmi                                0
# under-five_deaths                  0
# polio                              0
# total_expenditure                  0
# diphtheria                         0
# hiv/aids                           0
# gdp                                0
# population                         0
# thinness__1-19_years               0
# thinness_5-9_years                 0
# income_composition_of_resources    0
# schooling                          0
# infant_deaths_ratio                0
# under_five_deaths_ratio            0
# dtype: int64

# %%
#Filtre
df[df.country == 'Afghanistan'].describe()
# Out:
#               year  life_expectancy  adult_mortality  infant_deaths  \
# count    16.000000        16.000000        16.000000      16.000000
# mean   2007.500000        58.193750       269.062500      78.250000
# std       4.760952         2.380607        72.760309       9.341663
# min    2000.000000        54.800000         3.000000      62.000000
# 25%    2003.750000        56.925000       271.750000      70.500000
# 50%    2007.500000        57.800000       284.000000      81.000000
# 75%    2011.250000        59.275000       295.000000      87.000000
# max    2015.000000        65.000000       321.000000      88.000000
#
#          alcohol  percentage_expenditure  hepatitis_b      measles        bmi  \
# count  16.000000               16.000000      16.0000    16.000000  16.000000
# mean    0.014375                0.001795      64.5625  2362.250000  15.518750
# std     0.007274                0.001567       1.8246  2272.066328   2.219075
# ...

# %%
#Test
df.aggregate(["sum"])
# Out:
#                                                country     year  \
# sum  AfghanistanAfghanistanAfghanistanAfghanistanAf...  4620138
#
#                                                 status  life_expectancy  \
# sum  DevelopingDevelopingDevelopingDevelopingDevelo...    156455.574795
#
#      adult_mortality  infant_deaths      alcohol  percentage_expenditure  \
# sum    408354.389344          81704  10244.10332               78.570057
#
#        hepatitis_b  measles  ...     diphtheria  hiv/aids         gdp  \
# sum  185019.004612  6512582  ...  186188.157588    4645.7  124.684666
#
#        population  thinness__1-19_years  thinness_5-9_years  \
# sum  3.111311e+10          12310.949931        12338.390771
#
#      income_composition_of_resources   schooling  infant_deaths_ratio  \
# sum                      1393.892413  1289.63977           627.782303
#
#      under_five_deaths_ratio
# sum               805.319273
#
# [1 rows x 24 columns]

# %%
df.groupby(['country', 'year']).mean(numeric_only=True)
# Out:
#                   life_expectancy  adult_mortality  infant_deaths   alcohol  \
# country     year
# Afghanistan 2000             54.8            321.0           88.0  0.010000
#             2001             55.3            316.0           88.0  0.010000
#             2002             56.2              3.0           88.0  0.010000
#             2003             56.7            295.0           87.0  0.010000
#             2004             57.0            293.0           87.0  0.020000
# ...                           ...              ...            ...       ...
# Zimbabwe    2009             50.0            587.0           30.0  4.640000
#             2010             52.4            527.0           29.0  5.210000
#             2011             54.9            464.0           28.0  6.000000
#             2014             59.2            371.0           23.0  6.500000
#             2015             67.0            336.0           22.0  4.602861
#
# ...

# %%
df.groupby(['status'])['life_expectancy'].mean()
# Out:
# status
# Developed     78.832099
# Developing    66.185023
# Name: life_expectancy, dtype: float64

# %%
df.groupby(['year'])['life_expectancy'].mean()
# Out:
# year
# 2000    66.316981
# 2001    66.950909
# 2002    67.192727
# 2003    66.925767
# 2004    66.997484
# 2005    67.283108
# 2006    67.666447
# 2007    68.375694
# 2008    68.508333
# 2009    69.164138
# 2010    68.973684
# 2011    69.136765
# 2012    69.127907
# 2013    68.819487
# 2014    68.834454
# 2015    68.488596
# Name: life_expectancy, dtype: float64

# %%
pd.crosstab(df['country'], df['status'])
# Out:
# status                              Developed  Developing
# country
# Afghanistan                                 0          16
# Albania                                     0          15
# Algeria                                     0          15
# Angola                                      0          15
# Antigua and Barbuda                         0          14
# ...                                       ...         ...
# Venezuela (Bolivarian Republic of)          0          12
# Viet Nam                                    0          11
# Yemen                                       0          15
# Zambia                                      0          14
# Zimbabwe                                    0          14
#
# [178 rows x 2 columns]

# %%
df['life_expectancy'].corr(df['bmi'])
# Out:
# 0.7037990806449129

# %%
correlation_matrix = df.corr(numeric_only=True)
print("Correlation between Life expectancy and BMI:", correlation_matrix.loc['life_expectancy', 'bmi'])
mp.figure(figsize=(12, 8)) 
sb.heatmap(correlation_matrix, cmap="YlGnBu", annot=True)
mp.show()
# Out:
# Correlation between Life expectancy and BMI: 0.7037990806449141

# %%
correlation_matrix = df.corr(numeric_only=True)
print("Correlation between Life expectancy and BMI:", correlation_matrix.loc['life_expectancy', 'bmi'])

filtered_correlation = correlation_matrix.where(correlation_matrix > 0.50, np.nan)
print(filtered_correlation)

mp.figure(figsize=(12, 8))

sb.heatmap(filtered_correlation, cmap="YlGnBu", annot=True, mask=filtered_correlation.isnull())
mp.show()
# Out:
# Correlation between Life expectancy and BMI: 0.7037990806449141
#                                  year  life_expectancy  adult_mortality  \
# year                              1.0              NaN              NaN
# life_expectancy                   NaN         1.000000              NaN
# adult_mortality                   NaN              NaN         1.000000
# infant_deaths                     NaN              NaN              NaN
# alcohol                           NaN              NaN              NaN
# percentage_expenditure            NaN              NaN              NaN
# hepatitis_b                       NaN              NaN              NaN
# measles                           NaN              NaN              NaN
# bmi                               NaN         0.703799              NaN
# under-five_deaths                 NaN              NaN              NaN
# polio                             NaN              NaN              NaN
# ...

# %%
df.columns.str.strip().str.replace(' ', '_').str.lower()
# Out:
# Index(['country', 'year', 'status', 'life_expectancy', 'adult_mortality',
#        'infant_deaths', 'alcohol', 'percentage_expenditure', 'hepatitis_b',
#        'measles', 'bmi', 'under-five_deaths', 'polio', 'total_expenditure',
#        'diphtheria', 'hiv/aids', 'gdp', 'population', 'thinness__1-19_years',
#        'thinness_5-9_years', 'income_composition_of_resources', 'schooling',
#        'infant_deaths_ratio', 'under_five_deaths_ratio'],
#       dtype='object')

# %%
# Analyse des corrélations principales
selected_columns = [
    'life_expectancy', 'adult_mortality', 'hiv/aids', 
    'gdp', 'income_composition_of_resources', 'schooling'
]

# Corrélations entre les indicateurs sélectionnés
correlation_matrix = df[selected_columns].corr()
print(correlation_matrix)

# Visualisation de la matrice de corrélation
mp.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
mp.title('Matrice de corrélation des indicateurs clés')
mp.show()
# Out:
#                                  life_expectancy  adult_mortality  hiv/aids  \
# life_expectancy                         1.000000        -0.684364 -0.560552
# adult_mortality                        -0.684364         1.000000  0.516863
# hiv/aids                               -0.560552         0.516863  1.000000
# gdp                                     0.430848        -0.266952 -0.130045
# income_composition_of_resources         0.677317        -0.415056 -0.233739
# schooling                               0.701240        -0.407865 -0.201094
#
#                                       gdp  income_composition_of_resources  \
# life_expectancy                  0.430848                         0.677317
# adult_mortality                 -0.266952                        -0.415056
# hiv/aids                        -0.130045                        -0.233739
# gdp                              1.000000                         0.438132
# ...

# %%
# Relation entre l'espérance de vie et les indicateurs clés
key_indicators = ['adult_mortality', 'hiv/aids', 'gdp', 'income_composition_of_resources', 'schooling']

for indicator in key_indicators:
    mp.figure(figsize=(8, 6))
    sns.scatterplot(x=indicator, y='life_expectancy', data=df)
    mp.title(f'Relation entre life_expectancy et {indicator}')
    mp.xlabel(indicator)
    mp.ylabel('life_expectancy')
    mp.show()

# %%
# Analyse par statut des pays (développés vs en développement)
status_grouped = df.groupby('status')[selected_columns].mean()

print(status_grouped)

# Visualisation des moyennes par statut
status_grouped.plot(kind='bar', figsize=(12, 8))
mp.title('Moyennes des indicateurs par statut des pays')
mp.xlabel('Status')
mp.ylabel('Valeurs moyennes')
mp.legend(loc='upper right')
mp.show()
# Out:
#             life_expectancy  adult_mortality  hiv/aids       gdp  \
# status
# Developed         78.832099        83.709877  0.100000  0.188685
# Developing        66.185023       192.736294  2.332305  0.032129
#
#             income_composition_of_resources  schooling
# status
# Developed                          0.844734   0.748472
# Developing                         0.566329   0.529391
